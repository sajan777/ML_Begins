# %%
from matplotlib import pyplot as plt
x=[1,5,10,20,25]
y=[34,46,78,99,101]
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.grid()
plt.title('FirstGraph')
plt.plot(x,y,color='green',marker='@',linewidth=5,linestyle= '-.')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\users\halfdevil\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\markers.py in set_marker(self, marker)
#     310             try:
# --> 311                 Path(marker)
#     312                 self._marker_function = self._set_vertices
#
# c:\users\halfdevil\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\path.py in __init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     126         """
# --> 127         vertices = _to_unmasked_float_array(vertices)
#     128         if vertices.ndim != 2 or vertices.shape[1] != 2:
#
# c:\users\halfdevil\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\cbook\__init__.py in _to_unmasked_float_array(x)
#    1364     else:
# -> 1365         return np.asarray(x, float)
#    1366
#
# ...
